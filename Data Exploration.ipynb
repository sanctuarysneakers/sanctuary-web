# %% [markdown]
# # Use this notebook to explore sneaker Data

# %%
import mysql.connector
from mysql.connector import ProgrammingError
import pandas as pd

# %%
host = "test-database-1.cmamugrum56i.us-west-2.rds.amazonaws.com"
user = "admin"
passwd = "password"
db_name = "sneakers"
try:
    conn = mysql.connector.connect(host=host, user=user, passwd=passwd, database=db_name)
    c = conn.cursor()
    c.execute("USE sneakers;")
except ProgrammingError:
    print("couldn't connect to database")

# %%
goat = pd.read_sql('SELECT * FROM goat_sneakers', con=conn)
grailed = pd.read_sql('SELECT * FROM grailed_sneakers', con=conn)
stockx = pd.read_sql('SELECT * FROM stockx_sneakers', con=conn)
flightclub = pd.read_sql('SELECT * FROM flightclub_sneakers', con=conn)

# %%
goat
# Out:
#             id source                                              model  \
# 0           53   Goat                Air Jordan 12 Low Retro 'Wolf Grey'
# 1           54   Goat  Union LA x Air Jordan 1 Retro High NRG 'Storm ...
# 2           62   Goat               Air Jordan 13 Retro Low 'Pure Money'
# 3           70   Goat                 Air Jordan 11 Retro 'Concord' 2018
# 4           80   Goat                 Air Jordan 11 Retro 'Concord' 2018
# ...        ...    ...                                                ...
# 15656  9253234   Goat              Air Jordan 1 Low SE 'Nothing But Net'
# 15657  9253240   Goat         Air Jordan 1 Retro High OG 'Black Gym Red'
# 15658  9253320   Goat                    Air Jordan 1 Low 'Reverse Bred'
# 15659  9253472   Goat                      Air Jordan 1 Low 'Game Royal'
# 15660  9253618   Goat                      Air Jordan 1 Mid 'Pine Green'
#
#            sku_id  size  price  shoe_condition       category  trending  \
# 0      308317-002  12.0     70            used  Air Jordan 12         0
# 1      BV1300-146   9.5   1924  new_no_defects   Air Jordan 1         0
# 2      310810-100   9.5     75            used  Air Jordan 13         0
# 3      378037-100  12.0    506  new_no_defects  Air Jordan 11         0
# 4      378037-100   8.5    465  new_no_defects  Air Jordan 11         0
# ...           ...   ...    ...             ...            ...       ...
# 15656  CZ8659-100   8.0    120  new_no_defects   Air Jordan 1         0
# 15657  555088-060  10.5    105  new_no_defects   Air Jordan 1         0
# 15658  553558-606  15.0    140  new_no_defects   Air Jordan 1         0
# 15659  553558-124  16.0    150  new_no_defects   Air Jordan 1         0
# 15660  554724-067  10.5    100  new_no_defects   Air Jordan 1         0
#
#        just_dropped                                                url  \
# 0                 0  https://www.goat.com/sneakers/air-jordan-12-lo...
# 1                 0  https://www.goat.com/sneakers/union-x-air-jord...
# 2                 0  https://www.goat.com/sneakers/air-jordan-13-re...
# 3                 0  https://www.goat.com/sneakers/air-jordan-11-re...
# 4                 0  https://www.goat.com/sneakers/air-jordan-11-re...
# ...             ...                                                ...
# 15656             0  https://www.goat.com/sneakers/air-jordan-1-low...
# 15657             0  https://www.goat.com/sneakers/air-jordan-1-ret...
# 15658             0  https://www.goat.com/sneakers/air-jordan-1-low...
# 15659             0  https://www.goat.com/sneakers/air-jordan-1-low...
# 15660             0  https://www.goat.com/sneakers/air-jordan-1-mid...
#
#                                                    image
# 0      https://image.goat.com/750/attachments/product...
# 1      https://image.goat.com/750/attachments/product...
# 2      https://image.goat.com/750/attachments/product...
# 3      https://image.goat.com/750/attachments/product...
# 4      https://image.goat.com/750/attachments/product...
# ...                                                  ...
# 15656  https://image.goat.com/750/attachments/product...
# 15657  https://image.goat.com/750/attachments/product...
# 15658  https://image.goat.com/750/attachments/product...
# 15659  https://image.goat.com/750/attachments/product...
# 15660  https://image.goat.com/750/attachments/product...
#
# [15661 rows x 12 columns]

# %%
grailed
# Out:
#              id   source                                     model  sku_id  \
# 0        316700  Grailed                 Air Jordan 11 retro 72-20    None
# 1        379980  Grailed                        air jordan 6-17-23    None
# 2        380205  Grailed              Jordan FLTCLB 80's 599583402    None
# 3        421633  Grailed             Jordan retro 6 gmp size 13 ds    None
# 4        466001  Grailed                      jordan 5 retro grape    None
# ...         ...      ...                                       ...     ...
# 10995  16063860  Grailed   Air Jordan 4 Retro 2017 Pure Money 2017  113189
# 10996  16064054  Grailed    Air Jordan 11 Retro Platinum Tint 2018  112148
# 10997  16064068  Grailed  Air Jordan 4 Retro Motorsports Alternate  113221
# 10998  16064193  Grailed        Air Jordan 3 Retro 2018 Mocha 2018  112636
# 10999  16064372  Grailed                Air Jordan 1 High OG CO.JP  111283
#
#        size  price    shoe_condition             category  old_price  \
# 0      10.0    270  is_not_specified         Jordan Brand      300.0
# 1       8.0     97  is_not_specified         Jordan Brand      108.0
# 2       8.0     74  is_not_specified         Jordan Brand       83.0
# 3      13.0    215  is_not_specified         Jordan Brand      270.0
# 4      13.0    108  is_not_specified         Jordan Brand      120.0
# ...     ...    ...               ...                  ...        ...
# 10995  12.0    230    is_gently_used         Jordan Brand        NaN
# 10996  10.5    200    is_gently_used         Jordan Brand        NaN
# 10997  11.5    150           is_used         Jordan Brand        NaN
# 10998  10.5    150           is_used  Jordan Brand × Nike        NaN
# 10999  10.5    325            is_new         Jordan Brand        NaN
#
#       date_bumped  ... seller_rating_count  shipping_us shipping_ca  \
# 0      2016-01-10  ...                   1         40.0        40.0
# 1      2016-02-20  ...                 132         20.0        15.0
# 2      2016-01-25  ...                 129         20.0        15.0
# 3      2016-02-11  ...                   0          8.0        20.0
# 4      2016-03-02  ...                   0          8.0        20.0
# ...           ...  ...                 ...          ...         ...
# 10995  2020-08-04  ...                  11         12.0         NaN
# 10996  2020-08-04  ...                   2         11.0         NaN
# 10997  2020-08-04  ...                   3          8.0        25.0
# 10998  2020-08-04  ...                  73         20.0        40.0
# 10999  2020-08-04  ...                  13         13.0         NaN
#
#        shipping_uk  shipping_eu  shipping_asia  shipping_au  shipping_other  \
# 0             15.0         30.0           50.0         50.0            25.0
# 1             45.0         45.0           55.0         55.0            25.0
# 2             45.0         45.0           55.0         55.0            25.0
# 3             25.0         25.0           25.0         25.0            25.0
# 4             25.0         25.0           25.0         25.0            25.0
# ...            ...          ...            ...          ...             ...
# 10995          NaN          NaN            NaN          NaN             NaN
# 10996          NaN          NaN            NaN          NaN             NaN
# 10997         25.0         25.0           25.0         25.0            25.0
# 10998          NaN          NaN            NaN          NaN             NaN
# 10999          NaN          NaN            NaN          NaN             NaN
#
#                                  url  \
# 0        grailed.com/listings/316700
# 1        grailed.com/listings/379980
# 2        grailed.com/listings/380205
# 3        grailed.com/listings/421633
# 4        grailed.com/listings/466001
# ...                              ...
# 10995  grailed.com/listings/16063860
# 10996  grailed.com/listings/16064054
# 10997  grailed.com/listings/16064068
# 10998  grailed.com/listings/16064193
# 10999  grailed.com/listings/16064372
#
#                                                    image
# 0      https://d1qz9pzgo5wm5k.cloudfront.net/api/file...
# 1      https://cdn.fs.grailed.com/api/file/OaRfnJoiQH...
# 2      https://cdn.fs.grailed.com/api/file/cU1cDVlqS1...
# 3      https://cdn.fs.grailed.com/api/file/KVQn2wRR7m...
# 4      https://cdn.fs.grailed.com/api/file/yOWMJvyWT7...
# ...                                                  ...
# 10995  https://cdn.fs.grailed.com/api/file/tCoXcraeTG...
# 10996  https://cdn.fs.grailed.com/api/file/MXqLTLMRm6...
# 10997  https://cdn.fs.grailed.com/api/file/ulpmwzR6OB...
# 10998  https://cdn.fs.grailed.com/api/file/5ZRAPxDgSG...
# 10999  https://cdn.fs.grailed.com/api/file/OW156thhRq...
#
# [11000 rows x 24 columns]

# %%
stockx
# Out:
#            id  source                                              model  \
# 0        1330  StockX  Jordan 1 Retro High Homage To Home (Non-numbered)
# 1        1808  StockX   Jordan 1 Retro High CO Japan Neutral Grey (2020)
# 2        8616  StockX                       Jordan 8 Retro Quai54 (2019)
# 3        9187  StockX        Jordan 1 Retro High Comme des Garcons White
# 4        9624  StockX                     Jordan 1 Retro Human Highlight
# ...       ...     ...                                                ...
# 7626  9993285  StockX               Jordan 13 Retro 3M Reflective Silver
# 7627  9994949  StockX                  Jordan 18 Retro White Sport Royal
# 7628  9996088  StockX                           Jordan Legacy 312 Knicks
# 7629  9997867  StockX               Jordan Legacy 312 Rookie of the Year
# 7630  9999418  StockX                       Jordan Legacy 312 Low Lakers
#
#           sku_id  size  price shoe_condition             category  \
# 0     861428-061   7.0    554            New       Air Jordan One
# 1     DC1788-029  12.0    295            New       Air Jordan One
# 2     CJ9218-001  10.0    455            New     Air Jordan Eight
# 3     CN5738-100   6.0    399            New       Air Jordan One
# 4     555088-017   7.0    875            New       Air Jordan One
# ...          ...   ...    ...            ...                  ...
# 7626  696298-023  13.0    350            New  Air Jordan Thirteen
# 7627  AA2494-106  11.5    310            New  Air Jordan Eighteen
# 7628  AV3922-048   8.0    179            New     Air Jordan Other
# 7629  AV3922-102  10.0    168            New     Air Jordan Other
# 7630  CD7069-102   9.0    185            New     Air Jordan Other
#
#       recently_sold  annual_sold  retail_price  highest_bid  \
# 0               NaN         69.0         160.0        451.0
# 1              26.0         55.0         170.0        294.0
# 2               1.0         39.0         190.0        207.0
# 3               NaN         16.0         350.0        250.0
# 4               0.0          1.0         140.0        109.0
# ...             ...          ...           ...          ...
# 7626            0.0         11.0         185.0        221.0
# 7627            0.0          9.0         225.0        226.0
# 7628            1.0         10.0         150.0         43.0
# 7629            NaN        122.0         150.0        137.0
# 7630            0.0         15.0         140.0        130.0
#
#       annual_high_price  annual_low_price  average_price  volatility  \
# 0                 627.0             342.0          422.0    0.116434
# 1                 431.0             265.0          309.0    0.103092
# 2                 323.0             128.0          178.0    0.148703
# 3                 450.0             200.0          372.0    0.400709
# 4                 310.0             310.0          310.0    0.000000
# ...                 ...               ...            ...         ...
# 7626              284.0             157.0          206.0    0.171315
# 7627              398.0             225.0          287.0    0.252515
# 7628              158.0              60.0           77.0    0.176949
# 7629              142.0              75.0          113.0    0.083054
# 7630              138.0              94.0          107.0    0.078179
#
#       number_of_asks  number_of_bids  \
# 0                 10               6
# 1                 46              34
# 2                  5               7
# 3                  7               3
# 4                  1               3
# ...              ...             ...
# 7626               2               5
# 7627               2               7
# 7628               1               4
# 7629               2              13
# 7630               1               4
#
#                                                     url  \
# 0     stockx.com/air-jordan-1-retro-high-homage-to-h...
# 1     stockx.com/air-jordan-1-retro-high-co-japan-ne...
# 2             stockx.com/air-jordan-8-retro-quai54-2019
# 3     stockx.com/air-jordan-1-retro-high-comme-des-g...
# 4             stockx.com/jordan-1-retro-human-highlight
# ...                                                 ...
# 7626    stockx.com/jordan-13-retro-3m-reflective-silver
# 7627   stockx.com/air-jordan-18-retro-white-sport-royal
# 7628            stockx.com/air-jordan-legacy-312-knicks
# 7629  stockx.com/air-jordan-legacy-312-rookie-of-the...
# 7630        stockx.com/air-jordan-legacy-312-low-lakers
#
#                                                   image
# 0     https://stockx.imgix.net/Air-Jordan-1-Retro-Hi...
# 1     https://stockx.imgix.net/Air-Jordan-1-Retro-Hi...
# 2     https://stockx.imgix.net/Air-Jordan-8-Retro-Qu...
# 3     https://stockx.imgix.net/Air-Jordan-1-Retro-Hi...
# 4     https://stockx.imgix.net/Air-Jordan-1-Retro-Hu...
# ...                                                 ...
# 7626  https://stockx.imgix.net/Air-Jordan-13-Retro-3...
# 7627  https://stockx.imgix.net/Air-Jordan-18-Retro-W...
# 7628  https://stockx.imgix.net/Air-Jordan-Legacy-312...
# 7629  https://stockx.imgix.net/Air-Jordan-Legacy-312...
# 7630  https://stockx.imgix.net/Air-Jordan-Legacy-312...
#
# [7631 rows x 20 columns]

# %%
flightclub
# Out:
#            id       source                                        model  \
# 0        1274  Flight Club    Air Jordan 1 Retro High SB 'NYC to Paris'
# 1        4683  Flight Club        Jordan Why Not Zer0.2 'Flash Crimson'
# 2        5152  Flight Club             Air Jordan 33 PF 'Metallic Gold'
# 3        5575  Flight Club             Air Jordan 1 Retro 'Chlorophyll'
# 4        7327  Flight Club          Air Jordan 5 Retro DB 'Doernbecher'
# ...       ...          ...                                          ...
# 8652  9997120  Flight Club             Air Jordan 3 Retro 'Infrared 23'
# 8653  9997565  Flight Club               Jordan Legacy 312 'Hyper Jade'
# 8654  9998318  Flight Club            w aj1 rebel xx 'The 1 Reimagined'
# 8655  9999126  Flight Club     Air Jordan 6 Retro Premium 'Motorsports'
# 8656  9999954  Flight Club  CLOT x Air Jordan 13 Retro Low 'Infra-Bred'
#
#           sku_id  size  price    category shoe_condition  \
# 0     CD6578-006   7.0    750  Air Jordan            New
# 1     AQ3562-002  10.5     89  Air Jordan            New
# 2     BV5072-016   8.5    165  Air Jordan            New
# 3           None  10.5    260  Air Jordan            New
# 4     633068-010  13.0   1170  Air Jordan            New
# ...          ...   ...    ...         ...            ...
# 8652  136064-123  10.0    450  Air Jordan            New
# 8653  AV3922-348  10.5    150  Air Jordan            New
# 8654        None   4.0    280  Air Jordan            New
# 8655  395866-101   8.5    450  Air Jordan            New
# 8656  AT3102-006  10.5    395  Air Jordan            New
#
#                                                     url  \
# 0     https://www.flightclub.com/air-jordan-1-retro-...
# 1     https://www.flightclub.com/jordan-why-not-zer0...
# 2     https://www.flightclub.com/air-jordan-33-pf-bl...
# 3     https://www.flightclub.com/air-jordan-1-retro-...
# 4     https://www.flightclub.com/air-jordan-5-retro-...
# ...                                                 ...
# 8652  https://www.flightclub.com/air-jordan-3-retro-...
# 8653  https://www.flightclub.com/jordan-legacy-312-h...
# 8654  https://www.flightclub.com/w-aj1-rebel-xx-crea...
# 8655  https://www.flightclub.com/air-jordan-6-premiu...
# 8656  https://www.flightclub.com/clot-x-air-jordan-1...
#
#                                                   image
# 0     https://cdn.flightclub.com/750/TEMPLATE/135711...
# 1     https://cdn.flightclub.com/750/TEMPLATE/160498...
# 2     https://cdn.flightclub.com/750/TEMPLATE/140474...
# 3     https://cdn.flightclub.com/750/TEMPLATE/011072...
# 4     https://cdn.flightclub.com/750/TEMPLATE/011806...
# ...                                                 ...
# 8652  https://cdn.flightclub.com/750/TEMPLATE/011871...
# 8653  https://cdn.flightclub.com/750/TEMPLATE/134728...
# 8654  https://cdn.flightclub.com/750/TEMPLATE/805199...
# 8655  https://cdn.flightclub.com/750/TEMPLATE/011171...
# 8656  https://cdn.flightclub.com/750/TEMPLATE/806317...
#
# [8657 rows x 10 columns]
